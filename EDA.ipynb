# %% [markdown]
# # Dataset Weather/BMKG
# # kelompok BMKG_4

# %% [markdown]
# ### Tahap Eksplorasi data

# %%
from datetime import datetime, timedelta
import time
from collections import namedtuple
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
import os.path

# %%
dataset_path="openweatherdata-denpasar-1990-2020.csv"

# %%
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#                 dt                         dt_iso  timezone city_name  \
# 0        631152000  1990-01-01 00:00:00 +0000 UTC     28800  Denpasar
# 1        631155600  1990-01-01 01:00:00 +0000 UTC     28800  Denpasar
# 2        631159200  1990-01-01 02:00:00 +0000 UTC     28800  Denpasar
# 3        631162800  1990-01-01 03:00:00 +0000 UTC     28800  Denpasar
# 4        631166400  1990-01-01 04:00:00 +0000 UTC     28800  Denpasar
# ...            ...                            ...       ...       ...
# 264919  1578423600  2020-01-07 19:00:00 +0000 UTC     28800  Denpasar
# 264920  1578427200  2020-01-07 20:00:00 +0000 UTC     28800  Denpasar
# 264921  1578430800  2020-01-07 21:00:00 +0000 UTC     28800  Denpasar
# 264922  1578434400  2020-01-07 22:00:00 +0000 UTC     28800  Denpasar
# 264923  1578438000  2020-01-07 23:00:00 +0000 UTC     28800  Denpasar
#
#              lat         lon   temp  temp_min  temp_max  pressure  ...  \
# 0      -8.652497  115.219117  25.82     25.82     25.82    1010.0  ...
# 1      -8.652497  115.219117  26.20     26.20     26.20    1011.0  ...
# 2      -8.652497  115.219117  26.45     26.45     26.45    1011.0  ...
# 3      -8.652497  115.219117  26.80     26.80     26.80    1011.0  ...
# 4      -8.652497  115.219117  27.04     27.04     27.04    1010.0  ...
# ...          ...         ...    ...       ...       ...       ...  ...
# 264919 -8.652497  115.219117  27.00     27.00     27.00    1007.0  ...
# 264920 -8.652497  115.219117  27.00     27.00     27.00    1007.0  ...
# 264921 -8.652497  115.219117  28.00     28.00     28.00    1007.0  ...
# 264922 -8.652497  115.219117  28.00     28.00     28.00    1007.0  ...
# 264923 -8.652497  115.219117  28.00     28.00     28.00    1008.0  ...
#
#         snow_3h  snow_6h  snow_12h  snow_24h  snow_today  clouds_all  \
# 0           NaN      NaN       NaN       NaN         NaN          98
# 1           NaN      NaN       NaN       NaN         NaN          91
# 2           NaN      NaN       NaN       NaN         NaN          94
# 3           NaN      NaN       NaN       NaN         NaN          94
# 4           NaN      NaN       NaN       NaN         NaN          76
# ...         ...      ...       ...       ...         ...         ...
# 264919      NaN      NaN       NaN       NaN         NaN          75
# 264920      NaN      NaN       NaN       NaN         NaN          75
# 264921      NaN      NaN       NaN       NaN         NaN          75
# 264922      NaN      NaN       NaN       NaN         NaN          40
# 264923      NaN      NaN       NaN       NaN         NaN          40
#
#         weather_id  weather_main  weather_description  weather_icon
# 0              500          Rain           light rain           10d
# 1              500          Rain           light rain           10d
# 2              500          Rain           light rain           10d
# 3              500          Rain           light rain           10d
# 4              803        Clouds        broken clouds           04d
# ...            ...           ...                  ...           ...
# 264919         803        Clouds        broken clouds           04n
# 264920         803        Clouds        broken clouds           04n
# 264921         803        Clouds        broken clouds           04n
# 264922         802        Clouds     scattered clouds           03n
# 264923         802        Clouds     scattered clouds           03d
#
# [264924 rows x 32 columns]

# %% [markdown]
# ### Date time Preporcessing

# %%
from dateutil import tz

# %%
converted_dt = pd.to_datetime(dataset['dt'], unit='s')
print(converted_dt)
# Out:
# 0        1990-01-01 00:00:00
# 1        1990-01-01 01:00:00
# 2        1990-01-01 02:00:00
# 3        1990-01-01 03:00:00
# 4        1990-01-01 04:00:00
#                  ...
# 264919   2020-01-07 19:00:00
# 264920   2020-01-07 20:00:00
# 264921   2020-01-07 21:00:00
# 264922   2020-01-07 22:00:00
# 264923   2020-01-07 23:00:00
# Name: dt, Length: 264924, dtype: datetime64[ns]

# %%
dataset.insert(2, 'date', converted_dt)
dataset
# Out:
#                 dt                         dt_iso                date  \
# 0        631152000  1990-01-01 00:00:00 +0000 UTC 1990-01-01 00:00:00
# 1        631155600  1990-01-01 01:00:00 +0000 UTC 1990-01-01 01:00:00
# 2        631159200  1990-01-01 02:00:00 +0000 UTC 1990-01-01 02:00:00
# 3        631162800  1990-01-01 03:00:00 +0000 UTC 1990-01-01 03:00:00
# 4        631166400  1990-01-01 04:00:00 +0000 UTC 1990-01-01 04:00:00
# ...            ...                            ...                 ...
# 264919  1578423600  2020-01-07 19:00:00 +0000 UTC 2020-01-07 19:00:00
# 264920  1578427200  2020-01-07 20:00:00 +0000 UTC 2020-01-07 20:00:00
# 264921  1578430800  2020-01-07 21:00:00 +0000 UTC 2020-01-07 21:00:00
# 264922  1578434400  2020-01-07 22:00:00 +0000 UTC 2020-01-07 22:00:00
# 264923  1578438000  2020-01-07 23:00:00 +0000 UTC 2020-01-07 23:00:00
#
#         timezone city_name       lat         lon   temp  temp_min  temp_max  \
# 0          28800  Denpasar -8.652497  115.219117  25.82     25.82     25.82
# 1          28800  Denpasar -8.652497  115.219117  26.20     26.20     26.20
# 2          28800  Denpasar -8.652497  115.219117  26.45     26.45     26.45
# 3          28800  Denpasar -8.652497  115.219117  26.80     26.80     26.80
# 4          28800  Denpasar -8.652497  115.219117  27.04     27.04     27.04
# ...          ...       ...       ...         ...    ...       ...       ...
# 264919     28800  Denpasar -8.652497  115.219117  27.00     27.00     27.00
# 264920     28800  Denpasar -8.652497  115.219117  27.00     27.00     27.00
# 264921     28800  Denpasar -8.652497  115.219117  28.00     28.00     28.00
# 264922     28800  Denpasar -8.652497  115.219117  28.00     28.00     28.00
# 264923     28800  Denpasar -8.652497  115.219117  28.00     28.00     28.00
#
#         ...  snow_3h  snow_6h  snow_12h  snow_24h  snow_today  clouds_all  \
# 0       ...      NaN      NaN       NaN       NaN         NaN          98
# 1       ...      NaN      NaN       NaN       NaN         NaN          91
# 2       ...      NaN      NaN       NaN       NaN         NaN          94
# 3       ...      NaN      NaN       NaN       NaN         NaN          94
# 4       ...      NaN      NaN       NaN       NaN         NaN          76
# ...     ...      ...      ...       ...       ...         ...         ...
# 264919  ...      NaN      NaN       NaN       NaN         NaN          75
# 264920  ...      NaN      NaN       NaN       NaN         NaN          75
# 264921  ...      NaN      NaN       NaN       NaN         NaN          75
# 264922  ...      NaN      NaN       NaN       NaN         NaN          40
# 264923  ...      NaN      NaN       NaN       NaN         NaN          40
#
#         weather_id  weather_main  weather_description  weather_icon
# 0              500          Rain           light rain           10d
# 1              500          Rain           light rain           10d
# 2              500          Rain           light rain           10d
# 3              500          Rain           light rain           10d
# 4              803        Clouds        broken clouds           04d
# ...            ...           ...                  ...           ...
# 264919         803        Clouds        broken clouds           04n
# 264920         803        Clouds        broken clouds           04n
# 264921         803        Clouds        broken clouds           04n
# 264922         802        Clouds     scattered clouds           03n
# 264923         802        Clouds     scattered clouds           03d
#
# [264924 rows x 33 columns]

# %%
dataset = dataset.set_index('date')

# %%
dataset.head(100)
# Out:
#                             dt                         dt_iso  timezone  \
# date
# 1990-01-01 00:00:00  631152000  1990-01-01 00:00:00 +0000 UTC     28800
# 1990-01-01 01:00:00  631155600  1990-01-01 01:00:00 +0000 UTC     28800
# 1990-01-01 02:00:00  631159200  1990-01-01 02:00:00 +0000 UTC     28800
# 1990-01-01 03:00:00  631162800  1990-01-01 03:00:00 +0000 UTC     28800
# 1990-01-01 04:00:00  631166400  1990-01-01 04:00:00 +0000 UTC     28800
# ...                        ...                            ...       ...
# 1990-01-04 23:00:00  631494000  1990-01-04 23:00:00 +0000 UTC     28800
# 1990-01-05 00:00:00  631497600  1990-01-05 00:00:00 +0000 UTC     28800
# 1990-01-05 01:00:00  631501200  1990-01-05 01:00:00 +0000 UTC     28800
# 1990-01-05 02:00:00  631504800  1990-01-05 02:00:00 +0000 UTC     28800
# 1990-01-05 03:00:00  631508400  1990-01-05 03:00:00 +0000 UTC     28800
#
#                     city_name       lat         lon   temp  temp_min  \
# date
# 1990-01-01 00:00:00  Denpasar -8.652497  115.219117  25.82     25.82
# 1990-01-01 01:00:00  Denpasar -8.652497  115.219117  26.20     26.20
# 1990-01-01 02:00:00  Denpasar -8.652497  115.219117  26.45     26.45
# 1990-01-01 03:00:00  Denpasar -8.652497  115.219117  26.80     26.80
# 1990-01-01 04:00:00  Denpasar -8.652497  115.219117  27.04     27.04
# ...                       ...       ...         ...    ...       ...
# 1990-01-04 23:00:00  Denpasar -8.652497  115.219117  27.15     27.15
# 1990-01-05 00:00:00  Denpasar -8.652497  115.219117  27.40     27.40
# 1990-01-05 01:00:00  Denpasar -8.652497  115.219117  27.55     27.55
# 1990-01-05 02:00:00  Denpasar -8.652497  115.219117  27.75     27.75
# 1990-01-05 03:00:00  Denpasar -8.652497  115.219117  27.94     27.94
#
#                      temp_max  pressure  ...  snow_3h  snow_6h  snow_12h  \
# date                                     ...
# 1990-01-01 00:00:00     25.82    1010.0  ...      NaN      NaN       NaN
# 1990-01-01 01:00:00     26.20    1011.0  ...      NaN      NaN       NaN
# 1990-01-01 02:00:00     26.45    1011.0  ...      NaN      NaN       NaN
# 1990-01-01 03:00:00     26.80    1011.0  ...      NaN      NaN       NaN
# 1990-01-01 04:00:00     27.04    1010.0  ...      NaN      NaN       NaN
# ...                       ...       ...  ...      ...      ...       ...
# 1990-01-04 23:00:00     27.15    1007.0  ...      NaN      NaN       NaN
# 1990-01-05 00:00:00     27.40    1008.0  ...      NaN      NaN       NaN
# 1990-01-05 01:00:00     27.55    1008.0  ...      NaN      NaN       NaN
# 1990-01-05 02:00:00     27.75    1009.0  ...      NaN      NaN       NaN
# 1990-01-05 03:00:00     27.94    1008.0  ...      NaN      NaN       NaN
#
#                      snow_24h  snow_today  clouds_all  weather_id  \
# date
# 1990-01-01 00:00:00       NaN         NaN          98         500
# 1990-01-01 01:00:00       NaN         NaN          91         500
# 1990-01-01 02:00:00       NaN         NaN          94         500
# 1990-01-01 03:00:00       NaN         NaN          94         500
# 1990-01-01 04:00:00       NaN         NaN          76         803
# ...                       ...         ...         ...         ...
# 1990-01-04 23:00:00       NaN         NaN         100         804
# 1990-01-05 00:00:00       NaN         NaN         100         804
# 1990-01-05 01:00:00       NaN         NaN         100         500
# 1990-01-05 02:00:00       NaN         NaN         100         804
# 1990-01-05 03:00:00       NaN         NaN         100         804
#
#                      weather_main  weather_description  weather_icon
# date
# 1990-01-01 00:00:00          Rain           light rain           10d
# 1990-01-01 01:00:00          Rain           light rain           10d
# 1990-01-01 02:00:00          Rain           light rain           10d
# 1990-01-01 03:00:00          Rain           light rain           10d
# 1990-01-01 04:00:00        Clouds        broken clouds           04d
# ...                           ...                  ...           ...
# 1990-01-04 23:00:00        Clouds      overcast clouds           04d
# 1990-01-05 00:00:00        Clouds      overcast clouds           04d
# 1990-01-05 01:00:00          Rain           light rain           10d
# 1990-01-05 02:00:00        Clouds      overcast clouds           04d
# 1990-01-05 03:00:00        Clouds      overcast clouds           04d
#
# [100 rows x 32 columns]
